# %% [markdown]
# # HCR-Net
# An implementation of the paper: "Chauhan, V. K., Singh, S., & Sharma, A. (2022).
# HCR-Net: A deep learning based script independent handwritten character recognition network. arXiv preprint arXiv:2108.06663."
#
# @author:
#     Vinod Kumar Chauhan,
#     Department of Engineering,
#     University of Oxford, UK
#     Email id: jmdvinodjmd@gmail.com / vinod.kumar@eng.ox.ac.uk
#
# Created on: June 2021, Last modified on: August, 2022.

# %% [markdown]
# ### HCR-Net (with image-augmentation)

# %%
##############################################################################
import logging
logging.getLogger("tensorflow").disabled = True
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense
from tensorflow.keras.layers import BatchNormalization as BatchNorm

# pre-trained models
from keras.applications.vgg16 import VGG16

# custom learning rates
import learning_rate as lr

# %matplotlib inline

##############################################################################
# please change following for your dataset (dataset details and learning params)
# dataset details
train_data_dir = './Data/Offline/UCI_DevanagariHandwrittenCharacterDataset/digits/Train'
validation_data_dir = './Data/Offline/UCI_DevanagariHandwrittenCharacterDataset/digits/Test'
nb_train_samples = 17000
nb_validation_samples = 3000
num_classes = 10

# learning params
epochs1 = 10
epochs2 = 50
learning_rate1 = lr.decayed_learning_rate
learning_rate2 = lr.decayed_learning_rate_tuned50

# set seeds for reproduceability
np.random.seed(1)
tf.random.set_seed(1)
##############################################################################
batch_size = 32
# dimensions of our images.
img_width, img_height = 32, 32
input_shape = (img_width, img_height, 3)
##############################################################################
#### TRAINING PHASE - I #########
#################################
# using VGG16: load model without classifier layer, and using weights from ImageNet
source_model = VGG16(include_top=False, input_shape=input_shape)

# create a new model using lower layers of VGG16 upto block4_conv2,
# and mark as not trainable, i.e., freeze the lower layers
model = Sequential()
for layer in source_model.layers[:-6]:
    layer.trainable = False
    model.add(layer)

# add extra layers at top of lower layers of pre-trained VGG16
model.add(BatchNorm())
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(512, activation='relu'))
model.add(BatchNorm())
model.add(Dropout(0.35))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# using ImageDataGenerator to load, augment and scale data
train_datagen = ImageDataGenerator(
                    rescale=1.0/255,
                    rotation_range=10,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.1,
                    zoom_range=0.05,
                    fill_mode='constant',
                    cval = 0
                )
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
                    train_data_dir,
                    target_size=(img_width, img_height),
                    batch_size=batch_size,
                    color_mode="rgb",
                    class_mode='categorical',
                    shuffle=True,
                    seed=13)
validation_generator = test_datagen.flow_from_directory(
                    validation_data_dir,
                    target_size=(img_width, img_height),
                    batch_size=nb_validation_samples,
                    color_mode="rgb",
                    shuffle=False,
                    class_mode='categorical')

# define callback for custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(learning_rate1)

history1 = model.fit(
                train_generator,
                steps_per_epoch=nb_train_samples // batch_size,
                epochs=epochs1,
                callbacks=[callback],
                validation_data=validation_generator,
                validation_steps=1)

# save the model
model.save_weights('./results/HCR-Net-Aug-I.weights.h5')

#################################
#### TRAINING PHASE - II #########
#################################
# fine tuning the model by unfreezing the lower layers (used from VGG16)
for layer in model.layers[:12]:
    layer.trainable = True

# reset the image generators
train_generator.reset()
validation_generator.reset()

# recompile the model
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
print(model.summary())

# define callback for custom learning rate
callback = tf.keras.callbacks.LearningRateScheduler(learning_rate2)

history2 = model.fit(
                train_generator,
                steps_per_epoch=nb_train_samples // batch_size,
                epochs=epochs2,
                callbacks=[callback],
                validation_data=validation_generator,
                validation_steps=1)

# save the model
model.save_weights('./results/HCR-Net-Aug-II.weights.h5')

##############################################################################
# plot the convergence, in terms of accuracy and loss
plt.plot(history1.history['accuracy']+history2.history['accuracy'])
plt.plot(history1.history['val_accuracy']+history2.history['val_accuracy'])
# plt.title('model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

plt.plot(history1.history['loss']+history2.history['loss'])
plt.plot(history1.history['val_loss']+history2.history['val_loss'])
# plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# evaluate model and plot confusion matrix
# filenames = validation_generator.filenames
predict = model.predict(validation_generator)
y_pred = np.argmax(predict,axis=-1)
cf_matrix = confusion_matrix(validation_generator.classes,y_pred)

# calculate size of confusion matrix figure, and plot it
fig, ax = plt.subplots(figsize=(math.ceil(num_classes/3.0), math.ceil(num_classes/3.0)))
labels = list(validation_generator.class_indices.keys())
sns.heatmap(cf_matrix, annot=True, xticklabels=labels, yticklabels=labels, fmt='', cmap='Blues')
plt.ylabel('Actual Class')
plt.xlabel('Predicted Class')
##############################################################################
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)                │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 4, 4, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 4, 4, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       4,194,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,744,202 (37.17 MB)
#  Trainable params: 4,465,674 (17.04 MB)
#  Non-trainable params: 5,278,528 (20.14 MB)
# None
# Found 17000 images belonging to 10 classes.
# Found 3000 images belonging to 10 classes.
# Epoch 1/10
# C:\Users\Kaleb\PycharmProjects\ProjectCode\venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 101s 187ms/step - accuracy: 0.9190 - loss: 0.2674 - val_accuracy: 0.9973 - val_loss: 0.0068 - learning_rate: 1.0000e-04
# Epoch 2/10
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 94us/step - accuracy: 0.9688 - loss: 0.0167 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 3/10
# C:\Users\Kaleb\AppData\Local\Programs\Python\Python39\lib\contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 33s 61ms/step - accuracy: 0.9918 - loss: 0.0296 - val_accuracy: 0.9980 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 4/10
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 5/10
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 32s 60ms/step - accuracy: 0.9951 - loss: 0.0172 - val_accuracy: 0.9973 - val_loss: 0.0056 - learning_rate: 1.0000e-04
# Epoch 6/10
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 36us/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 7/10
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 32s 59ms/step - accuracy: 0.9962 - loss: 0.0142 - val_accuracy: 0.9990 - val_loss: 0.0029 - learning_rate: 5.0000e-05
# Epoch 8/10
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 9/10
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 32s 61ms/step - accuracy: 0.9975 - loss: 0.0076 - val_accuracy: 0.9993 - val_loss: 0.0019 - learning_rate: 5.0000e-05
# Epoch 10/10
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 1.0000 - loss: 8.4107e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-05
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)                │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 4, 4, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 4, 4, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       4,194,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,744,202 (37.17 MB)
#  Trainable params: 9,741,130 (37.16 MB)
#  Non-trainable params: 3,072 (12.00 KB)
# None
# Epoch 1/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 74s 135ms/step - accuracy: 0.9978 - loss: 0.0061 - val_accuracy: 0.9993 - val_loss: 0.0018 - learning_rate: 1.0000e-07
# Epoch 2/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 85us/step - accuracy: 1.0000 - loss: 7.0131e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 3/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 72s 134ms/step - accuracy: 0.9990 - loss: 0.0052 - val_accuracy: 0.9993 - val_loss: 0.0018 - learning_rate: 1.0000e-07
# Epoch 4/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 1.0000 - loss: 7.1985e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-07
# Epoch 5/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 72s 135ms/step - accuracy: 0.9984 - loss: 0.0068 - val_accuracy: 0.9993 - val_loss: 0.0018 - learning_rate: 1.0000e-07
# Epoch 6/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 45us/step - accuracy: 1.0000 - loss: 5.9460e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 7/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 72s 136ms/step - accuracy: 0.9987 - loss: 0.0042 - val_accuracy: 0.9983 - val_loss: 0.0030 - learning_rate: 5.0000e-06
# Epoch 8/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 1.0000 - loss: 1.0186e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 9/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 72s 135ms/step - accuracy: 0.9994 - loss: 0.0041 - val_accuracy: 0.9990 - val_loss: 0.0022 - learning_rate: 5.0000e-06
# Epoch 10/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 1.0000 - loss: 9.5660e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 11/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 72s 134ms/step - accuracy: 0.9989 - loss: 0.0044 - val_accuracy: 0.9993 - val_loss: 0.0022 - learning_rate: 5.0000e-06
# Epoch 12/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 6.6301e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 13/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 72s 135ms/step - accuracy: 0.9990 - loss: 0.0046 - val_accuracy: 0.9993 - val_loss: 0.0018 - learning_rate: 5.0000e-06
# Epoch 14/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 1.0000 - loss: 5.1912e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 15/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 71s 134ms/step - accuracy: 0.9988 - loss: 0.0040 - val_accuracy: 0.9990 - val_loss: 0.0017 - learning_rate: 5.0000e-06
# Epoch 16/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 55us/step - accuracy: 1.0000 - loss: 1.0044e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 17/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 71s 134ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9993 - val_loss: 0.0022 - learning_rate: 5.0000e-06
# Epoch 18/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 9.9661e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 19/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 75s 141ms/step - accuracy: 0.9990 - loss: 0.0035 - val_accuracy: 0.9977 - val_loss: 0.0031 - learning_rate: 5.0000e-06
# Epoch 20/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 2.6321e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 21/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 74s 140ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9980 - val_loss: 0.0026 - learning_rate: 5.0000e-06
# Epoch 22/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 1.0000 - loss: 6.3915e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 23/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 72s 135ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 0.9997 - val_loss: 9.2839e-04 - learning_rate: 5.0000e-06
# Epoch 24/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 1.5193e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 25/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 74s 140ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9993 - val_loss: 0.0015 - learning_rate: 5.0000e-06
# Epoch 26/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 2.5627e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 27/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 71s 134ms/step - accuracy: 0.9995 - loss: 0.0023 - val_accuracy: 0.9993 - val_loss: 0.0018 - learning_rate: 5.0000e-06
# Epoch 28/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 1.1271e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 29/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 70s 132ms/step - accuracy: 0.9997 - loss: 0.0021 - val_accuracy: 0.9997 - val_loss: 0.0015 - learning_rate: 5.0000e-06
# Epoch 30/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 31/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 71s 133ms/step - accuracy: 0.9995 - loss: 0.0027 - val_accuracy: 0.9997 - val_loss: 9.7287e-04 - learning_rate: 5.0000e-06
# Epoch 32/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 33/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 72s 135ms/step - accuracy: 0.9992 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0011 - learning_rate: 5.0000e-06
# Epoch 34/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 43us/step - accuracy: 1.0000 - loss: 8.8319e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 35/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 69s 129ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9993 - val_loss: 0.0014 - learning_rate: 5.0000e-06
# Epoch 36/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 1.0000 - loss: 6.1664e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 37/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 70s 132ms/step - accuracy: 0.9996 - loss: 0.0042 - val_accuracy: 0.9987 - val_loss: 0.0023 - learning_rate: 5.0000e-06
# Epoch 38/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 1.0000 - loss: 2.1907e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 39/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 68s 128ms/step - accuracy: 0.9992 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0010 - learning_rate: 5.0000e-06
# Epoch 40/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 45us/step - accuracy: 1.0000 - loss: 2.5547e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 41/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 70s 131ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.9997 - val_loss: 0.0012 - learning_rate: 5.0000e-06
# Epoch 42/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 5.1512e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 43/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 69s 129ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 7.9487e-04 - learning_rate: 5.0000e-06
# Epoch 44/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 40us/step - accuracy: 1.0000 - loss: 2.5513e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-06
# Epoch 45/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 69s 129ms/step - accuracy: 0.9998 - loss: 9.7206e-04 - val_accuracy: 1.0000 - val_loss: 6.0055e-04 - learning_rate: 5.0000e-06
# Epoch 46/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 4.8088e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 47/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 69s 130ms/step - accuracy: 0.9998 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 5.7894e-04 - learning_rate: 1.0000e-06
# Epoch 48/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 1.0000 - loss: 2.1607e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-06
# Epoch 49/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 70s 132ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 5.7943e-04 - learning_rate: 1.0000e-06
# Epoch 50/50
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 0s 42us/step - accuracy: 1.0000 - loss: 3.7714e-06 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Text(0.5, 14.581597222222216, 'Predicted Class')

# %%
# calculate different metrics for HCR-Net on the test dataset
print('precision_score: ', precision_score(validation_generator.classes,y_pred, average="macro"))
print('recall_score   : ', recall_score(validation_generator.classes,y_pred, average="macro"))
print('f1_score       : ', f1_score(validation_generator.classes,y_pred, average="macro"))
print('accuracy_score : ', accuracy_score(validation_generator.classes,y_pred, normalize=True))

print("\nBest accuracy  : ", max(max(history1.history['val_accuracy']), max(history2.history['val_accuracy'])))
# Out:
# precision_score:  1.0
# recall_score   :  1.0
# f1_score       :  1.0
# accuracy_score :  1.0
#
# Best accuracy  :  1.0
